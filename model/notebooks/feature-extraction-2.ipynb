# %%
import pandas as pd
import pickle

# %%
df: pd.DataFrame = pickle.load(open('../data/processed-data/feature-extraction-1.pkl', 'rb'))

# %%
df = df[['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left', 'wickets_left', 'crr', 'final_score']]

# %%
df = df.sample(df.shape[0])

# %%
df
# Out:
#        batting_team bowling_team         city  current_score  balls_left  \
# 8125          India  West Indies       London             45          77
# 29595     Australia  West Indies       London              1         117
# 48231  South Africa     Pakistan        Dubai            120          25
# 37221     Australia    Sri Lanka     Adelaide             52          91
# 1368   South Africa  New Zealand     Auckland             68          68
# ...             ...          ...          ...            ...         ...
# 16268  South Africa    Sri Lanka      Colombo             12          99
# 40682   New Zealand        India     Hamilton             22         102
# 43636       England  New Zealand     Auckland             79          75
# 36820   West Indies  New Zealand   Wellington            124          20
# 4491      Sri Lanka      England  Southampton            163           1
#
#        wickets_left        crr  final_score
# 8125              7   6.279070          153
# ...

# %%
pickle.dump(df, open('../data/processed-data/feature-extraction-2.pkl', 'wb'))
